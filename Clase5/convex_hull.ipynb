# %% [markdown]
# # Convex Hull Transform
#
# Images to use:
#
#   - [horse.jpg ](https://drive.google.com/file/d/16yWrtoiXhWVj-Ex3OgDk9Z_hgiwxAm7I/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

from skimage.morphology import convex_hull_image
from skimage import img_as_float
import cv2
import numpy as np

# %%
# Load image - horse.jpg (grayscale)
image = cv2.imread("/content/drive/MyDrive/Docencia/Patrones/2022-2/L14/patrones/Clase5/horse.jpg", 0)

plt.imshow(image, cmap="gray")
print(image.shape, np.max(image), np.min(image))
# Out:
# (295, 360) 255 0

# %%
# Binarize image (as required by convex_hull_image)
image = image > 127

c_hull = convex_hull_image(image)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Display original image
axes[0].set_title('Original picture')
axes[0].imshow( image , cmap = "gray")
axes[0].set_axis_off()

# Display convex hull transform
axes[1].set_title('Transformed picture')
axes[1].imshow(c_hull, cmap = "gray")
axes[1].set_axis_off()

plt.tight_layout()
plt.show()

# %%
print(image[:5, :5], c_hull[:5,:5])
# Out:
# [[False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]] [[False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]
#  [False False False False False]]

# %%
# Estimate the difference between convex hull and original image
c_hull_diff = img_as_float( c_hull )
print (c_hull_diff.max(), c_hull_diff.min())
# Out:
# 1.0 0.0

# %%
c_hull_diff = c_hull * 1.0
print(c_hull_diff.max(), c_hull_diff.min())
# Out:
# 1.0 0.0

# %%
# use other form
print (np.max(c_hull_diff))
c_hull_diff[image] = 2

fig, ax = plt.subplots()
ax.imshow(c_hull_diff, cmap = "gray")
ax.set_title('Difference')
ax.set_axis_off()
plt.show()
# Out:
# 1.0
