# %% [markdown]
# # **Are you sure of what you see? Playing with perspectives**
#
# Images to use:
#
#   - [sudoku1.jpg](https://drive.google.com/file/d/1iuwPQccftjsmSibrznc0hMM6mMERC7gY/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Take an image - sudoku1.jpg
image = cv2.imread("/content/drive/MyDrive/Docencia/Patrones/2022-2/L14/patrones/Clase4/sudoku1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# show image
_, ax = plt.subplots(figsize=(12,7))
plt.imshow(image)

# %%
# Select points
image = cv2.imread("/content/drive/MyDrive/Docencia/Patrones/2022-2/L14/patrones/Clase4/sudoku1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

cv2.circle(image, ( 370 , 170 ), 2, [0,0,255],2)
cv2.circle(image, ( 605 , 167 ), 2, [0,255,0],2)
cv2.circle(image, ( 360 , 385 ), 2, [255,0,0],2)
cv2.circle(image, ( 645 , 380 ), 2, [255,255,0],2)
plt.figure(figsize=(15,10))
plt.imshow(image)

# %%
# Confirm selected points
points = np.float32([[ 370 , 170 ],[ 605 , 167 ],[ 360 , 385 ],[ 645 , 380 ]])

# Create the output image we want
output_size = (300,300)
mapping = np.float32([[0,0],[300,0],[0,300],[300,300]])

# %%
Perspective = cv2.getPerspectiveTransform(points, mapping)
imagePerspective = cv2.warpPerspective(image, Perspective, output_size)

# %%
_, axes = plt.subplots(1,2, figsize = (15,10))
axes[0].imshow(image); axes[0].set_title('Input'); axes[0].set_axis_off()
axes[1].imshow(imagePerspective); axes[1].set_title('Output'); axes[1].set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Other example
#
# Repeat this for [sudoku2.jpg](https://drive.google.com/file/d/1Krk3E96urFMzf_oV3yDaHaMCZMb23571/view?usp=sharing) and [sudoku3.jpg](https://drive.google.com/file/d/1_gGeEDPRcVeESWmklRQxNfz4ESqzG4vH/view?usp=sharing)

# %%
# Take an image - sudoku2.jpg
image = 

plt.imshow(image)

# %%
# Select points
image = 

cv2.circle(image, ( _ , _ ), 2, [0,0,255],2)
cv2.circle(image, ( _ , _ ), 2, [0,0,255],2)
cv2.circle(image, ( _ , _ ), 2, [0,0,255],2)
cv2.circle(image, ( _ , _ ), 2, [0,0,255],2)
plt.figure(figsize=(15,10))

plt.imshow(image)

# Confirm selected points
points = np.float32([[ _ , _ ],[ _ , _ ],[ _ , _ ],[ _ , _ ]])

# Create the output image we want
output_size = (300,300)
mapping = np.float32([[0,0],[300,0],[0,300],[300,300]])

# %%
Perspective = cv2.getPerspectiveTransform(points,mapping)
imagePerspective = cv2.warpPerspective(image, Perspective, output_size)

# %%
_, axes = plt.subplots(1,2, figsize = (20,10))
axes[0].imshow(image); axes[0].set_title('Input'); axes[0].set_axis_off()
axes[1].imshow(imagePerspective); axes[1].set_title('Output'); axes[1].set_axis_off()
plt.show()
