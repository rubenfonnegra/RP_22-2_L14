# %% [markdown]
# # **Template Matching**
#
# Images to use:
#
#   - [original_golden_bridge.jpg](https://drive.google.com/file/d/1_CCfitpunMcFJqoCMlxvKaZpTzEUF9vB/view?usp=sharing)
#   - [portion_of_image.jpg](https://drive.google.com/file/d/1cy7yFvmkkmsAMSwdXdcJa5Gl2tbYTGgB/view?usp=sharing)
#   - [simpsons.jpg](https://drive.google.com/file/d/1hDsJVGbCqh4pqQ0gZpOAafTe-6mQtmKV/view?usp=sharing)
#   - [barts_face.jpg](https://drive.google.com/file/d/1IVM-fz0Jxwf3uOJRrH1keI92ReJbhtwE/view?usp=sharing)
#   - [super_mario.jpg](https://drive.google.com/file/d/1cEsUKOqEmYj_ogJHRUrSNZ3ykkNxd-4a/view?usp=sharing)
#   - [super_mario_coin.jpg](https://drive.google.com/file/d/1erZUbuPcUl1Lp_Ty4_pTdvPSVbCKheln/view?usp=sharing)

# %% [markdown]
# ## Example 1

# %% [markdown]
# Documentación de template matching en este [enlace](https://docs.opencv.org/4.x/df/dfb/group__imgproc__object.html)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load original_golden_bridge.jpg
original = cv2.imread("/content/original_golden_bridge.jpg")

# Load portion_of_image.jpg
template = cv2.imread("/content/portion_of_image.jpg")

# %%
# Convert images to grayscale
gray_img = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
template = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)

# Plot images
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(gray_img, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()
# Out:
# (<matplotlib.image.AxesImage at 0x7f85cb24cb90>,
#  Text(0.5, 1.0, 'Template'),
#  None)

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)

loc = np.where(result >= 0.1)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (0, 255, 0), 3)

# %%
# plot result
_, axes = plt.subplots(1, 2, figsize = (18,10))
axes[0].imshow(img_result), axes[0].set_title("Original"), axes[0].set_axis_off() 
axes[1].imshow(result, cmap = plt.cm.hot), axes[1].set_title("Conrrelations"), axes[1].set_axis_off()  # plt.cm.cool
plt.tight_layout()

# %% [markdown]
# ## Example 2

# %%
# Load simpsons.jpg
original = 

# Load barts_face.jpg
template =

# %%
# Convert images to grayscale
gray_img = 
template = 

# Plot images
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(gray_img, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.6)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (0, 255, 0), 3)

# %%
# plot result
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")

# %% [markdown]
# # **Matching multiple objects**

# %%
# Load super_mario.jpg
original = cv2.imread("/content/super_mario.jpg")

# Load super_mario_coin.jpg
template = cv2.imread("/content/super_mario_coin.jpg")

# %%
# Convert images to grayscale
gray_img = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
template = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)

# Plot images
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(gray_img, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()
# Out:
# (<matplotlib.image.AxesImage at 0x7f85c10e9cd0>,
#  Text(0.5, 1.0, 'Template'),
#  None)

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.35)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (255, 0, 0), 1)

# %%
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")
# Out:
# (<matplotlib.image.AxesImage at 0x7f85be51bc10>,
#  Text(0.5, 1.0, 'Original'),
#  (-0.5, 1199.5, 799.5, -0.5))

# %%
# Convert images to grayscale
gray_img = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)

#change template using borders detection 
template_b = cv2.Canny(template, 50, 255)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(template, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template_b, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()
# Out:
# (<matplotlib.image.AxesImage at 0x7f85c10b8190>,
#  Text(0.5, 1.0, 'Template'),
#  None)

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
img_border = cv2.Canny(gray_img, 50, 255)

result = cv2.matchTemplate(img_border, template_b, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.14)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (255, 0, 0), 3)

# %%
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")
# Out:
# (<matplotlib.image.AxesImage at 0x7f85be4fa110>,
#  Text(0.5, 1.0, 'Original'),
#  (-0.5, 1199.5, 799.5, -0.5))

# %% [markdown]
# ## Multi-scale objects

# %%
import imutils
import cv2
import numpy as np

# load the image image, convert it to grayscale, and detect edges
#template = cv2.imread("/content/images/tachy.png")
template = cv2.imread("/content/super_mario_coin.jpg")
template = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
template = cv2.Canny(template, 50, 100)
(tH, tW) = template.shape[:2]

# load the image, convert it to grayscale, and initialize the
# bookkeeping variable to keep track of the matched region
#image = cv2.imread("/content/NormalOne.png")
image = cv2.imread("/content/super_mario.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (8,5))
ax1.imshow(gray, cmap='gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap='gray'), ax2.set_title("Original"), ax2.set_axis_off()

# %%
found = None
for scale in np.linspace(0.1, 1.0, 50)[::-1]: # Multiscale
		# resize the image according to the scale, and keep track
		# of the ratio of the resizing
		resized = imutils.resize(gray, width = int(gray.shape[1] * scale))
		r = gray.shape[1] / float(resized.shape[1])
		# if the resized image is smaller than the template, then break
		# from the loop
		if resized.shape[0] < tH or resized.shape[1] < tW:
			  break
    # detect edges in the resized, grayscale image and apply template
		# matching to find the template in the image
		edged = cv2.Canny(resized, 50, 200)
		result = cv2.matchTemplate(edged, template, cv2.TM_CCOEFF)
		(_, maxVal, _, maxLoc) = cv2.minMaxLoc(result)
		# if we have found a new maximum correlation value, then update
		# the bookkeeping variable
		if found is None or maxVal > found[0]:
			  found = (maxVal, maxLoc, r)
			  # unpack the bookkeeping variable and compute the (x, y) coordinates
        # of the bounding box based on the resized ratio
			  (_, maxLoc, r) = found
			  (startX, startY) = (int(maxLoc[0] * r), int(maxLoc[1] * r))
			  (endX, endY) = (int((maxLoc[0] + tW) * r), int((maxLoc[1] + tH) * r))
			  # draw a bounding box around the detected result and display the image
			  cv2.rectangle(image, (startX, startY), (endX, endY), (0, 0, 255), 2)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (15,10))
plt.imshow(image), plt.title("Original"), plt.axis("off")

# %%
edged = cv2.Canny(gray, 50, 100)
plt.figure(figsize = (15,10))
plt.imshow(edged), plt.title("Original"), plt.axis("off")
